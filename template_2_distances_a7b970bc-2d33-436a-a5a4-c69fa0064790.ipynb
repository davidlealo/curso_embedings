# %% [markdown]
# # Cálculo de distancias de vectores con NumPy

# %% [markdown]
# ## Importar NumPy y cargar vectores

# %%
import numpy as np

# %%
gato = np.array()
perro = np.array()
computadora = np.array()

# %% [markdown]
# ## Dot product

# %%
dot_product_gato_perro = np.dot()
dot_product_gato_computadora = np.dot()

print('Producto punto gato-perro: ', )
print('Producto punto gato-computadora: ', )

# %% [markdown]
# ## Euclidean distance

# %%
euclidean_distance = np.linalg.norm()

print()

# %% [markdown]
# ## Cosine similarity

# %%
dot_product = np.dot()

norm_gato = np.linalg.norm()
norm_perro = np.linalg.norm()

cosine_similarity =
print()
